# %%
import pandas as pd
import os

# ==============================
# FILE PATHS
# ==============================
BASE_PATH = r"C:\Users\manu.chopra\OneDrive - Reliance Corporate IT Park Limited\Documents\ITSM_AI_Project"

SITES_FILE = os.path.join(BASE_PATH, "Sites.xlsx")
INVENTORY_FILE = os.path.join(BASE_PATH, "Inventory.xlsx")
COMPLAINTS_FILE = os.path.join(BASE_PATH, "Complaints.xlsx")

# ==============================
# LOAD MASTER DATA
# ==============================
sites_df = pd.read_excel(SITES_FILE)
inventory_df = pd.read_excel(INVENTORY_FILE)

# ------------------------------
# CLEAN DATA
# ------------------------------
sites_df.columns = sites_df.columns.str.strip()
inventory_df.columns = inventory_df.columns.str.strip()

sites_df["Site"] = sites_df["Site"].astype(str).str.strip().str.upper()
inventory_df["Site"] = inventory_df["Site"].astype(str).str.strip().str.upper()
inventory_df["Tag"] = inventory_df["Tag"].astype(str).str.strip().str.upper()
inventory_df["Device"] = inventory_df["Device"].astype(str).str.strip()

# ==============================
# LOAD OR CREATE COMPLAINTS FILE
# ==============================
if os.path.exists(COMPLAINTS_FILE):
    complaints_df = pd.read_excel(COMPLAINTS_FILE)
else:
    complaints_df = pd.DataFrame(columns=[
        "Complaint", "Site", "Manager", "STORESTATE",
        "STORECITY", "STORENAME", "Tag", "Device", "Title"
    ])

# ==============================
# GENERATE COMPLAINT NUMBER
# ==============================
def generate_complaint_no(df):
    if df.empty:
        return "IT00001"
    last = df["Complaint"].iloc[-1]
    num = int(last.replace("IT", ""))
    return f"IT{num+1:05d}"

# ==============================
# CHATBOT START
# ==============================
print("\n🤖 Welcome to Virtual IT Support Chatbot")
print("Enter Site Code OR Asset Tag (type 'exit' to quit)\n")

while True:
    user_input = input("Enter Site or Tag: ").strip().upper()

    if user_input == "EXIT":
        print("\nThank you. Session closed.")
        break

    # ------------------------------
    # SITE ENTERED
    # ------------------------------
    site_row = sites_df[sites_df["Site"] == user_input]

    if not site_row.empty:
        site = user_input
        print("✅ Site detected:", site_row["STORENAME"].values[0])

        tag = input("Enter Tag ID: ").strip().upper()
        inv_row = inventory_df[inventory_df["Tag"] == tag]

        if inv_row.empty:
            print("❌ Tag not found. Please restart and try again.\n")
            continue

        # 🔒 VALIDATE TAG BELONGS TO SITE
        if inv_row["Site"].values[0] != site:
            print("❌ Tag does NOT belong to this site.")
            print("Please provide correct Tag ID for site:", site)
            print()
            continue

    else:
        # ------------------------------
        # TAG ENTERED
        # ------------------------------
        inv_row = inventory_df[inventory_df["Tag"] == user_input]

        if inv_row.empty:
            print("❌ Site or Tag not found. Please restart.\n")
            continue

        tag = user_input
        site = inv_row["Site"].values[0]
        site_row = sites_df[sites_df["Site"] == site]

        print("✅ Tag detected for site:", site_row["STORENAME"].values[0])

    # ==============================
    # COMMON DETAILS
    # ==============================
    device = inv_row["Device"].values[0]
    title = input("Enter Complaint Title: ").strip()

    complaint_no = generate_complaint_no(complaints_df)

    new_row = {
        "Complaint": complaint_no,
        "Site": site,
        "Manager": site_row["Manager"].values[0],
        "STORESTATE": site_row["STORESTATE"].values[0],
        "STORECITY": site_row["STORECITY"].values[0],
        "STORENAME": site_row["STORENAME"].values[0],
        "Tag": tag,
        "Device": device,
        "Title": title
    }

    complaints_df = pd.concat(
        [complaints_df, pd.DataFrame([new_row])],
        ignore_index=True
    )

    complaints_df.to_excel(COMPLAINTS_FILE, index=False)

    print("\n✅ Complaint Registered Successfully")
    print("📌 Complaint Number:", complaint_no)
    print("Program will now close.")
    print("-" * 60)

    break   # 🛑 EXIT PROGRAM AFTER SUCCESS
# Out:
# 🤖 Welcome to Virtual IT Support Chatbot
# Enter Site Code OR Asset Tag (type 'exit' to quit)
# Enter Site or Tag:  S2463
# ✅ Site detected: General Stores   ADARI
# Enter Tag ID:  IA04042
# ❌ Tag does NOT belong to this site.
# Please provide correct Tag ID for site: S2463
# Enter Site or Tag:  IA04927
# ✅ Tag detected for site: General Stores   ADARI
# Enter Complaint Title:  laptop not working
# ✅ Complaint Registered Successfully
# 📌 Complaint Number: IT00003
# Program will now close.
# ------------------------------------------------------------

# %%
import os
import pandas as pd

BASE_PATH = r"C:\Users\manu.chopra\OneDrive - Reliance Corporate IT Park Limited\Documents\ITSM_AI_Project"

kedb_path = os.path.join(BASE_PATH, "KEDB.xlsx")
solution_path = os.path.join(BASE_PATH, "KEDB_Solution.xlsx")

# Load files
kedb_df = pd.read_excel(kedb_path)
solution_df = pd.read_excel(solution_path)

# Clean columns
kedb_df.columns = kedb_df.columns.str.strip()
solution_df.columns = solution_df.columns.str.strip()

# Merge on KEDB
full_kedb = kedb_df.merge(solution_df, on="KEDB", how="left")

print(full_kedb.head())
# Out:
#      KEDB       FORMAT CATEGORY SUBCATEGORY              ISSUE_TYPE  \
# 0  KM2985  BACK OFFICE  PRINTER     PRINTER            DRIVER ISSUE
# 1  KM2985  BACK OFFICE  PRINTER     PRINTER    FAINT PRINTING ISSUE
# 2  KM2985  BACK OFFICE  PRINTER     PRINTER         HARDWARE FAULTY
# 3  KM2985  BACK OFFICE  PRINTER     PRINTER     INK REFILLING ISSUE
# 4  KM2985  BACK OFFICE  PRINTER     PRINTER  PAPER PICKUP TRY ISSUE
#
#                                             Solution
# 0  1. Turn off the Printer\t\t\n\t\t1. Turn off t...
# 1  1. Turn off the Printer\t\t\n\t\t1. Turn off t...
# 2  1. Turn off the Printer\t\t\n\t\t1. Turn off t...
# 3  1. Turn off the Printer\t\t\n\t\t1. Turn off t...
# 4  1. Turn off the Printer\t\t\n\t\t1. Turn off t...

# %%
full_kedb["TEXT"] = (
    full_kedb["FORMAT"].fillna("") + " " +
    full_kedb["CATEGORY"].fillna("") + " " +
    full_kedb["SUBCATEGORY"].fillna("") + " " +
    full_kedb["ISSUE_TYPE"].fillna("")
)

X = full_kedb["TEXT"]
y = full_kedb["ISSUE_TYPE"]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    lowercase=True,
    stop_words="english",
    ngram_range=(1,2)
)

X_vec = vectorizer.fit_transform(X)

# %%
from sklearn.linear_model import LogisticRegression

model_issue = LogisticRegression(max_iter=1000)
model_issue.fit(X_vec, y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
import pickle

pickle.dump(vectorizer, open("kedb_vectorizer.pkl", "wb"))
pickle.dump(model_issue, open("kedb_issue_model.pkl", "wb"))

# %%
import os
import pandas as pd
import pickle

# ==============================
# BASE PATH (single source of truth)
# ==============================
BASE_PATH = r"C:\Users\manu.chopra\OneDrive - Reliance Corporate IT Park Limited\Documents\ITSM_AI_Project"

def p(file):
    return os.path.join(BASE_PATH, file)

# ==============================
# LOAD MODEL
# ==============================
vectorizer = pickle.load(open(p("kedb_vectorizer.pkl"), "rb"))
model_issue = pickle.load(open(p("kedb_issue_model.pkl"), "rb"))

# ==============================
# LOAD KEDB DATA
# ==============================
kedb_df = pd.read_excel(p("KEDB.xlsx"))
solution_df = pd.read_excel(p("KEDB_Solution.xlsx"))

kedb_df.columns = kedb_df.columns.str.strip()
solution_df.columns = solution_df.columns.str.strip()

full_kedb = kedb_df.merge(solution_df, on="KEDB", how="left")

# ==============================
# CHATBOT START
# ==============================
print("\n🤖 KEDB Virtual Support Engineer")
print("Describe the issue once. System will suggest all relevant solutions.\n")

query = input("Enter problem statement: ").strip()

# ==============================
# PREDICT ISSUE TYPE
# ==============================
vec = vectorizer.transform([query])
predicted_issue = model_issue.predict(vec)[0]

print("\n🔍 Predicted Issue Type:", predicted_issue)

# ==============================
# FILTER KNOWLEDGE BASE
# ==============================
matches = full_kedb[full_kedb["ISSUE_TYPE"] == predicted_issue]

# ==============================
# DISPLAY RESULTS
# ==============================
if matches.empty:
    print("\n❌ No KEDB solutions found.")
else:
    print("\n📘 Recommended Knowledge Articles")
    print("=" * 60)

    for _, row in matches.iterrows():
        print(f"\nKEDB ID     : {row['KEDB']}")
        print(f"Format     : {row['FORMAT']}")
        print(f"Category   : {row['CATEGORY']}")
        print(f"Subcategory: {row['SUBCATEGORY']}")
        print("Solution   :")
        print(f" - {row['Solution']}")

    print("\n✅ Total Solutions Found:", len(matches))

print("\nSession completed. Program closed.")
# Out:
# 🤖 KEDB Virtual Support Engineer
# Describe the issue once. System will suggest all relevant solutions.
# Enter problem statement:  monitor physical damage
# 🔍 Predicted Issue Type: PHYSICAL DAMAGE
#
# 📘 Recommended Knowledge Articles
# ============================================================
#
# KEDB ID     : KM2985
# Format     : BACK OFFICE
# Category   : PRINTER
# Subcategory: PRINTER
# Solution   :
#  - 1. Turn off the Printer
# 		1. Turn off the printer and unplug it from the power source.
# 		2. Disconnect any cables connected to the printer.
# 2. Physical Check
# 		Check for any cracks, dents, or broken parts on the casing, tray, or cover.
# 		Inspect the paper feed rollers for damage or misalignment.
# 		Look inside the printer for loose or broken components, including the carriage and ink cartridge slots.
# 		If the printer was dropped, check for internal dislodged parts.
# 3.  Remove the Paper Jam
# 	1. Access the Paper Tray:
# 		Open the paper tray and remove any loose paper.
# 	2. Clear Paper Path:
# 		Carefully remove any jammed paper from the input and output trays. Be gentle to avoid tearing the paper.
# 	3. Open the Rear Access Door (if available):
# 		Open the rear access door or duplexer.
# 		Gently pull out any jammed paper.
# 	4. Check Inside the Printer:
# 		Open the front cover or cartridge access door.
# 		Look inside for any paper jams and carefully remove them.
# 4. Check Rollers and Remove Debris
# 	1. Inspect Rollers:
# 		Check the paper feed rollers for any debris or small pieces of paper. Clean the rollers with a lint-free cloth dampened with distilled water if necessary.
# 5. Reassemble and Test
# 	1. Reassemble the Printer:
# 		Close all doors and replace any trays you removed.
# 	2. Reconnect and Power On:
# 		Plug the printer back in and turn it on.
# 	3. Test Print:
# 		Try printing a test page to ensure the issue is resolved.
# 6. Steps to Refill Ink:
# 	1. Preparation:
# 		Turn off the printer and unplug it from the power source.
# 		Place the printer on a stable surface with a protective layer (like an old cloth or paper) to catch any potential ink spills.
# 	2. Access the Ink Tank:
# 		Open the ink tank cover on the right side of the printer.
# 		Identify the ink tank that needs refilling.
# 	3. Open the Ink Tank Cap:
# 		Remove the cap from the ink tank. Ensure you do this carefully to avoid any ink spills.
# 	4. Prepare the Ink Bottle:
# 		Open the new ink bottle. If it’s a sealed bottle, remove the seal carefully.
# 		Attach the nozzle to the ink bottle if it has one.
# 	5. Refill the Ink Tank:
# 		Slowly pour the ink from the bottle into the ink tank. Be cautious not to overfill the tank; most tanks have a maximum fill line.
# 		If there’s any spill, clean it immediately with a cloth or paper towel.
# 	6. Secure the Ink Tank:
# 		Once filled, securely replace the ink tank cap.
# 		Close the ink tank cover.
# 7. Prevention Tips share with user
# 	1. Use Proper Paper:
# 		Ensure you use the correct type and size of paper recommended for your printer.
# 	2. Load Paper Correctly:
# 		Don't overload the paper tray. Align the paper properly and adjust the paper guides to fit the paper.
# 	3. Regular Maintenance:
# 		Clean the printer regularly to prevent dust build-up.
# 8. Professional Repair or Replacement
# 		Warranty: If your printer paper still getting stuck or JAM  under warranty, contact the manufacturer for support or a replacement.
# 		Professional Repair: If the printer paper still getting stuck or JAM is not under warranty and none of the above steps work, consider taking it to a professional for repair or replacing it.
#
#
# KEDB ID     : KM2985A
# Format     : BACK OFFICE
# Category   : PRINTER
# Subcategory: PRINTER
# Solution   :
#  - 1. Turn off the Printer
# 		1. Turn off the printer and unplug it from the power source.
# 		2. Disconnect any cables connected to the printer.
# 2. Physical Check
# 		Check for any cracks, dents, or broken parts on the casing, tray, or cover.
# 		Inspect the paper feed rollers for damage or misalignment.
# 		Look inside the printer for loose or broken components, including the carriage and ink cartridge slots.
# 		If the printer was dropped, check for internal dislodged parts.
# 3.  Remove the Paper Jam
# 	1. Access the Paper Tray:
# 		Open the paper tray and remove any loose paper.
# 	2. Clear Paper Path:
# 		Carefully remove any jammed paper from the input and output trays. Be gentle to avoid tearing the paper.
# 	3. Open the Rear Access Door (if available):
# 		Open the rear access door or duplexer.
# 		Gently pull out any jammed paper.
# 	4. Check Inside the Printer:
# 		Open the front cover or cartridge access door.
# 		Look inside for any paper jams and carefully remove them.
# 4. Check Rollers and Remove Debris
# 	1. Inspect Rollers:
# 		Check the paper feed rollers for any debris or small pieces of paper. Clean the rollers with a lint-free cloth dampened with distilled water if necessary.
# 5. Reassemble and Test
# 	1. Reassemble the Printer:
# 		Close all doors and replace any trays you removed.
# 	2. Reconnect and Power On:
# 		Plug the printer back in and turn it on.
# 	3. Test Print:
# 		Try printing a test page to ensure the issue is resolved.
# 6. Steps to Refill Ink:
# 	1. Preparation:
# 		Turn off the printer and unplug it from the power source.
# 		Place the printer on a stable surface with a protective layer (like an old cloth or paper) to catch any potential ink spills.
# 	2. Access the Ink Tank:
# 		Open the ink tank cover on the right side of the printer.
# 		Identify the ink tank that needs refilling.
# 	3. Open the Ink Tank Cap:
# 		Remove the cap from the ink tank. Ensure you do this carefully to avoid any ink spills.
# 	4. Prepare the Ink Bottle:
# 		Open the new ink bottle. If it’s a sealed bottle, remove the seal carefully.
# 		Attach the nozzle to the ink bottle if it has one.
# 	5. Refill the Ink Tank:
# 		Slowly pour the ink from the bottle into the ink tank. Be cautious not to overfill the tank; most tanks have a maximum fill line.
# 		If there’s any spill, clean it immediately with a cloth or paper towel.
# 	6. Secure the Ink Tank:
# 		Once filled, securely replace the ink tank cap.
# 		Close the ink tank cover.
# 7. Prevention Tips share with user
# 	1. Use Proper Paper:
# 		Ensure you use the correct type and size of paper recommended for your printer.
# 	2. Load Paper Correctly:
# 		Don't overload the paper tray. Align the paper properly and adjust the paper guides to fit the paper.
# 	3. Regular Maintenance:
# 		Clean the printer regularly to prevent dust build-up.
# 8. Professional Repair or Replacement
# 		Warranty: If your printer paper still getting stuck or JAM  under warranty, contact the manufacturer for support or a replacement.
# 		Professional Repair: If the printer paper still getting stuck or JAM is not under warranty and none of the above steps work, consider taking it to a professional for repair or replacing it.
#
# KEDB ID     : KM3001
# Format     : BACK OFFICE
# Category   : LAPTOP
# Subcategory: MONITOR / DISPLAY
# Solution   :
#  - 1. Assess the Damage
# 		Visual Inspection: Check for visible signs of damage, such as cracks, dents, or broken components.
# 		Functional Test: Attempt to power on the laptop and see if it boots. Check for display issues, keyboard functionality, and connectivity.
# 2. Safety Precautions
# 		Power Off: Ensure the laptop is turned off and disconnected from any power source.
# 		Discharge Static: Use an anti-static wrist strap or touch a grounded metal object to discharge any static electricity.
# 3. Disassemble the Laptop
# 		Back Up Data: If possible, remove the hard drive and back up any important data.
# 		Remove Battery: For laptops with removable batteries, take out the battery.
# 		Remove Screws: Use the appropriate screwdriver to remove the screws securing the bottom cover.
# 		Open the Case: Carefully pry open the bottom cover to access internal components.
# 4. Identify and Replace Damaged Components
# 		Screen Damage: If the screen is cracked or not displaying properly, replace it with a compatible screen.
# 		Keyboard Issues: Replace the keyboard if keys are missing or not functioning.
# 		Hinges: If the hinges are broken, replace them to ensure the screen opens and closes properly.
# 		Internal Components: Check for any damaged internal components, such as the motherboard, RAM, or storage. Replace as necessary.
# 5. Reassemble the Laptop
# 		Reattach Components: Secure all replaced components and ensure they are properly connected.
# 		Replace Screws: Reattach the bottom cover and secure it with screws.
# 		Reinsert Battery: If you removed the battery, put it back in place.
# 6. Test the Laptop
# 		Power On: Turn on the laptop and ensure it boots correctly.
# 		Functional Check: Test the display, keyboard, touchpad, and connectivity ports.
# 		Run Diagnostics: Use built-in diagnostics tools to check for any remaining issues.
# 7. Professional Repair or Replacement
# 		Warranty: If your Laptop hardware faulty or not working under warranty, contact the manufacturer for support or a replacement.
# 		Professional Repair: If the Laptop hardware faulty or not working is not under warranty and none of the above steps work, consider taking it to a professional for repair or replacing it.
#
# KEDB ID     : KM3043
# Format     : BACK OFFICE
# Category   : LAPTOP
# Subcategory: SYSTEM ISSUE
# Solution   :
#  - 1. Initial Checks
# 	1. Power Supply:
# 		Ensure the laptop is properly plugged into a power source.
# 		Check the power cable and adapter for any damages.
# 		Verify that the power outlet is working by plugging in another device.
# 	2. External Display:
# 		Connect the laptop to an external monitor using HDMI, VGA, or DisplayPort to check if the issue is with the laptop's display.
# 		If the external monitor works, the problem may be with the laptop's screen or internal connections.
# 2. Basic Troubleshooting
# 	1. Power Cycle:
# 		Turn off the laptop.
# 		Unplug the power adapter and remove the battery (if removable).
# 		Press and hold the power button for about 30 seconds to drain any residual power.
# 		Reconnect the battery and power adapter, then try turning on the laptop.
# 	2. Check Display Brightness:
# 		Make sure the display brightness is not set to the lowest level.
# 	3. Check Display Settings:
# 		Try toggling the display modes by pressing Fn + F4 (or relevant function key) to switch between laptop screen, external display, and mirrored displays.
# 3. Advanced Troubleshooting
# 	1. Reseat RAM:
# 		Turn off the laptop and unplug it.
# 		Open the back panel to access the RAM slots.
# 		Carefully remove and reseat the RAM modules.
# 		Close the back panel and try turning on the laptop.
# 	2. Reset BIOS/UEFI Settings:
# 		Press the BIOS/UEFI access key (usually F2, F10, Delete, or Esc) repeatedly while turning on the laptop.
# 		Once in the BIOS/UEFI menu, reset to default settings.
# 	3. Update/Reset Graphics Driver:
# 		If you can access the laptop in Safe Mode or using an external display, try updating or reinstalling the graphics driver from the Device Manager.
# 		Alternatively, boot into Safe Mode by pressing F8 during startup and selecting Safe Mode. Uninstall the graphics driver and restart.
# 	4. Check for Loose Connections:
# 		Open the laptop carefully and check if the display connector (LCD cable) is securely connected to the motherboard and display panel.
# 4. Specific Checks for Models
# 	Lenovo Laptops
# 		Use Lenovo Diagnostics Tool for hardware checks (can be accessed by pressing F10 during startup).
# 	HP Laptops
# 		Use HP PC Hardware Diagnostics (UEFI) by pressing Esc and then F2 during startup.
# 	Dell Vostro :
# 		Run Dell SupportAssist diagnostics by pressing F12 during startup and selecting Diagnostics.
# 5. Professional Repair or Replacement
# 		Warranty: If your Laptop hardware faulty or not working under warranty, contact the manufacturer for support or a replacement.
# 		Professional Repair: If the Laptop hardware faulty or not working is not under warranty and none of the above steps work, consider taking it to a professional for repair or replacing it.
#
# ✅ Total Solutions Found: 4
#
# Session completed. Program closed.
